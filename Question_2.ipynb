# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from numpy import log
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df_US = pd.read_excel("TCP23_data.xlsx", sheet_name = "Q2 Contributing Factors").iloc[1:34,27:33]
df_US
# Out:
#                  Unnamed: 27                                     Unnamed: 28  \
# 1                        NaN                                             NaN
# 2                        NaN                                             NaN
# 3                        NaN                                             NaN
# 4   Battery Cost (US$/kW-hr)  Battery Gravimetric Energy Densities (W-hr/kg)
# 5                        NaN                                              79
# 6                        NaN                                             NaN
# 7                        NaN                                             NaN
# 8                        NaN                                             105
# 9                       3200                                             110
# 10                       NaN                                             125
# 11                      2500                                             NaN
# 12                       NaN                                             140
# 13                      1800                                             NaN
# 14                       NaN                                             150
# 15                       NaN                                             155
# 16                       NaN                                             165
# 17                       830                                             NaN
# 18                       NaN                                             185
# 19                       630                                             195
# 20                       NaN                                             NaN
# 21                       NaN                                             NaN
# 22                       NaN                                             205
# 23                       NaN                                             NaN
# 24                       370                                             NaN
# 25                       NaN                                             NaN
# 26                       NaN                                             NaN
# 27                       NaN                                             240
# 28                       NaN                                             NaN
# 29                       350                                             NaN
# 30                       NaN                                             NaN
# 31                       NaN                                             NaN
# 32                       NaN                                             NaN
# 33                       NaN                                             NaN
#
#                                           Unnamed: 29  \
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Yearly average price of regular grade (87 octa...
# 5                                                 NaN
# 6                                               1.087
# 7                                               1.067
# 8                                               1.075
# 9                                               1.111
# 10                                              1.199
# 11                                              1.199
# 12                                               1.03
# 13                                              1.136
# 14                                              1.484
# 15                                               1.42
# 16                                              1.345
# 17                                              1.561
# 18                                              1.852
# 19                                               2.27
# 20                                              2.572
# 21                                              2.796
# 22                                              3.246
# 23                                              2.353
# 24                                              2.782
# 25                                              3.521
# 26                                              3.618
# 27                                              3.505
# 28                                              3.358
# 29                                              2.429
# 30                                              2.143
# 31                                              2.415
# 32                                              2.719
# 33                                              2.604
#
#                                     Unnamed: 30  \
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4   % People Considering Climate as Top 3 Issue
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                            7
# 26                                            7
# 27                                            7
# 28                                           10
# 29                                            9
# 30                                            9
# 31                                            9
# 32                                           13
# 33                                           25
#
#                                           Unnamed: 31
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Per capita Disposable Personal Income in the U...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                              33645
# 15                                              34216
# 16                                              34894
# 17                                              35474
# 18                                              36325
# 19                                              36526
# 20                                              37570
# 21                                              38093
# 22                                              38188
# 23                                              37814
# 24                                              38282
# 25                                              38769
# 26                                              39732
# 27                                              38947
# 28                                              40118
# 29                                              41383
# 30                                              41821
# 31                                              42699
# 32                                              43886
# 33                                              44644
